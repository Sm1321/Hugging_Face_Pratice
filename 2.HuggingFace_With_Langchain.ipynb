# %%
# !pip install langchain-huggingface -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 23.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 28.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 14.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 71.6 MB/s eta 0:00:00

# %%
# !pip install transformers -q
# !pip install accelerate -q
# !pip install  bitsandbytes -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 7.7 MB/s eta 0:00:00

# %%
# !pip install langchain_community -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 30.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 32.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 2.8 MB/s eta 0:00:00

# %%
# !pip install --upgrade transformers accelerate bitsandbytes -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 1.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 33.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.1/345.1 kB 15.1 MB/s eta 0:00:00

# %%
# !pip install huggingface_hub -q

# %% [markdown]
# ### Load the Hugging Face Token

# %%
from google.colab import userdata
hf_token=userdata.get('HF_TOKEN')

# %%
import os
os.environ["HUGGINGFACEHUB_API_TOKEN"] = hf_token

# %%
repo_id = "deepseek-ai/DeepSeek-R1"

# %%
from langchain import HuggingFaceHub

# %%
llm = HuggingFaceHub(repo_id = repo_id,
                     model_kwargs = {"temperature":0.1,"max_length":64})
# Out:
# <ipython-input-10-544b54cb65e2>:1: LangChainDeprecationWarning: The class `HuggingFaceHub` was deprecated in LangChain 0.0.21 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEndpoint``.
#   llm = HuggingFaceHub(repo_id = repo_id,

# %%
from langchain import PromptTemplate, LLMChain

# %%
question = "who is a first president of INDIA?"

# %%
template = """Quiestion: {queston}
give me a answer in detail manner and in step by step manner"""

prompt = PromptTemplate(template = template,
                        input_variables = ["question"]
                        )

# %%
prompt
# Out:
# PromptTemplate(input_variables=['queston'], input_types={}, partial_variables={}, template='Quiestion: {queston}\ngive me a answer in detail manner and in step by step manner')

# %%
llm.invoke("hello how are you?")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'post' (from 'huggingface_hub.inference._client') is deprecated and will be removed from version '0.31.0'. Making direct POST requests to the inference server is not supported anymore. Please use task methods instead (e.g. `InferenceClient.chat_completion`). If your use case is not supported, please open an issue in https://github.com/huggingface/huggingface_hub.
#   warnings.warn(warning_message, FutureWarning)
# 'hello how are you? I am fine. I am a bot. How can I help you today?'

# %%
llm_chain=LLMChain(llm = llm,
                   prompt = prompt)
# Out:
# <ipython-input-16-c1337b226581>:1: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   llm_chain=LLMChain(llm = llm,

# %%
llm_chain.invoke(question)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'post' (from 'huggingface_hub.inference._client') is deprecated and will be removed from version '0.31.0'. Making direct POST requests to the inference server is not supported anymore. Please use task methods instead (e.g. `InferenceClient.chat_completion`). If your use case is not supported, please open an issue in https://github.com/huggingface/huggingface_hub.
#   warnings.warn(warning_message, FutureWarning)
# {'queston': 'who is a first president of INDIA?',
#  'text': "Quiestion: who is a first president of INDIA?\ngive me a answer in detail manner and in step by step manner\n\nAnswer:\n\nSure, I'd be happy to provide a detailed and step-by-step answer to your question.\n\n**Step 1: Understanding the Context**\n\nThe first president of India was elected after India gained independence from British rule on August 15, 1947. The office of the President of India was established by the Constitution of India, which came into effect on January 26, 1950. This date is celebrated as Republic Day in India.\n\n**Step 2: The Election Process**\n\nThe first presidential election was held in 1952. The election was indirect, with an electoral college consisting of elected members of both houses of Parliament (Lok Sabha and Rajya Sabha) and state legislative assemblies. The Constitution provides for a five-year term for the President, with no term limits.\n\n**Step 3: The Candidates**\n\nThere were two main candidates for the first presidential election:\n\n1. **Dr. Rajendra Prasad**: He was a prominent Indian independence activist and a key leader of the Indian National Congress (INC), the party that dominated Indian politics at the time. He had played a significant role in the Indian independence movement and was the President of the Indian National Congress from 1934 to 1935 and again from 1948 to 1949.\n\n2. **S. Radhakrishnan**: He was a distinguished academic and statesman. He was the Vice President of India from 1952 to 1962 and served as the President of India from 1962 to 1967. He was also a philosopher and a scholar of comparative religion.\n\n**Step 4: The Election Results**\n\nThe election was held on April 21, 1952, and the results were declared on May 10, 1952. Dr. Rajendra Prasad won the election, securing 56% of the total votes cast by the electoral college.\n\n**Step 5: The Inauguration**\n\nDr. Rajendra Prasad was inaugurated as the first President of India on May 26, 1952, at the Durbar Hall of Rashtrapati Bhavan, New Delhi. He took the oath of office in the presence of the then Governor-General of India, C. Rajagopalachari, and other dignitaries.\n\n**Step 6: Dr. Rajendra Prasad's Presidency**\n\nDr. Rajendra Prasad served as the President of India for two terms, until May 12, 1962. His presidency was marked by several significant events, including the adoption of the Hindu Code Bills, the introduction of the Panchayati Raj system, and the handling of the Indo-China war in 1962.\n\n**Step 7: Legacy**\n\nDr. Rajendra Prasad is remembered as the first President of India and for his significant contributions to the Indian independence movement and the early years of the Indian Republic. He was also known for his simplicity and humility, often preferring to travel by train rather than by car, and living a modest lifestyle despite his high office.\n\nSo, in a step-by-step manner, Dr. Rajendra Prasad became the first President of India through a democratic election process, serving two terms from 1952 to 1962, and leaving a lasting legacy in Indian history."}

# %% [markdown]
# ### Load the Pipeline Class

# %%
from langchain_huggingface import HuggingFacePipeline

# %%
from transformers import AutoTokenizer, pipeline, AutoModelForCausalLM,BitsAndBytesConfig

# %%
model_name = "deepseek-ai/DeepSeek-R1"

# %%
from transformers import AutoConfig, AutoModelForCausalLM, AutoTokenizer

def load_deepseek_r1(model_name, trust_remote_code=True):
    config = AutoConfig.from_pretrained(model_name, trust_remote_code=trust_remote_code)
    if hasattr(config, "quantization_config"):
        delattr(config, "quantization_config")

    model = AutoModelForCausalLM.from_pretrained(
        model_name,
        config=config,
        trust_remote_code=trust_remote_code
    )

    tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=trust_remote_code)

    return model, tokenizer

model, tokenizer = load_deepseek_r1("deepseek-ai/DeepSeek-R1")
# Out:
# config.json:   0%|          | 0.00/1.73k [00:00<?, ?B/s]
# configuration_deepseek.py:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/deepseek-ai/DeepSeek-R1:
# - configuration_deepseek.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_deepseek.py:   0%|          | 0.00/75.8k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/deepseek-ai/DeepSeek-R1:
# - modeling_deepseek.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# model.safetensors.index.json:   0%|          | 0.00/8.90M [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/163 [00:00<?, ?it/s]
# model-00001-of-000163.safetensors:   0%|          | 0.00/5.23G [00:00<?, ?B/s]
# model-00002-of-000163.safetensors:   0%|          | 0.00/4.30G [00:00<?, ?B/s]
# model-00003-of-000163.safetensors:   0%|          | 0.00/4.30G [00:00<?, ?B/s]
# model-00004-of-000163.safetensors:   0%|          | 0.00/4.30G [00:00<?, ?B/s]
# model-00005-of-000163.safetensors:   0%|          | 0.00/4.30G [00:00<?, ?B/s]
# model-00006-of-000163.safetensors:   0%|          | 0.00/4.37G [00:00<?, ?B/s]
# model-00007-of-000163.safetensors:   0%|          | 0.00/4.31G [00:00<?, ?B/s]
# model-00008-of-000163.safetensors:   0%|          | 0.00/4.30G [00:00<?, ?B/s]
# model-00009-of-000163.safetensors:   0%|          | 0.00/4.30G [00:00<?, ?B/s]
# model-00010-of-000163.safetensors:   0%|          | 0.00/4.30G [00:00<?, ?B/s]
# model-00011-of-000163.safetensors:   0%|          | 0.00/4.30G [00:00<?, ?B/s]
# model-00012-of-000163.safetensors:   0%|          | 0.00/1.32G [00:00<?, ?B/s]
# model-00013-of-000163.safetensors:   0%|          | 0.00/4.30G [00:00<?, ?B/s]
# model-00014-of-000163.safetensors:   0%|          | 0.00/4.30G [00:00<?, ?B/s]
# model-00015-of-000163.safetensors:   0%|          | 0.00/4.30G [00:00<?, ?B/s]
# model-00016-of-000163.safetensors:   0%|          | 0.00/4.30G [00:00<?, ?B/s]
# model-00017-of-000163.safetensors:   0%|          | 0.00/4.30G [00:00<?, ?B/s]
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:651: UserWarning: Not enough free disk space to download the file. The expected file size is: 4302.35 MB. The target location /root/.cache/huggingface/hub/models--deepseek-ai--DeepSeek-R1/blobs only has 5.76 MB free disk space.
#   warnings.warn(
# model-00018-of-000163.safetensors:   0%|          | 0.00/4.30G [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-21-563ed5d11369> in <cell line: 0>()
#      16     return model, tokenizer
#      17
# ---> 18 model, tokenizer = load_deepseek_r1("deepseek-ai/DeepSeek-R1")
#
# <ipython-input-21-563ed5d11369> in load_deepseek_r1(model_name, trust_remote_code)
#       6         delattr(config, "quantization_config")
#       7
# ----> 8     model = AutoModelForCausalLM.from_pretrained(
#       9         model_name,
#      10         config=config,
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     557             cls.register(config.__class__, model_class, exist_ok=True)
#     558             model_class = add_generation_mixin_to_remote_model(model_class)
# --> 559             return model_class.from_pretrained(
#     560                 pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     561             )
#
# /usr/local/lib/python3.11/dist-packages/transformers/modeling_utils.py in _wrapper(*args, **kwargs)
#     260         old_dtype = torch.get_default_dtype()
#     261         try:
# --> 262             return func(*args, **kwargs)
#     263         finally:
#     264             torch.set_default_dtype(old_dtype)
#
# /usr/local/lib/python3.11/dist-packages/transformers/modeling_utils.py in from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    4020         if is_sharded:
#    4021             # resolved_archive_file becomes a list of files that point to the different checkpoint shards in this case.
# -> 4022             resolved_archive_file, sharded_metadata = get_checkpoint_shard_files(
#    4023                 pretrained_model_name_or_path,
#    4024                 resolved_archive_file,
#
# /usr/local/lib/python3.11/dist-packages/transformers/utils/hub.py in get_checkpoint_shard_files(pretrained_model_name_or_path, index_filename, cache_dir, force_download, proxies, resume_download, local_files_only, token, user_agent, revision, subfolder, _commit_hash, **deprecated_kwargs)
#    1035         try:
#    1036             # Load from URL
# -> 1037             cached_filename = cached_file(
#    1038                 pretrained_model_name_or_path,
#    1039                 shard_filename,
#
# /usr/local/lib/python3.11/dist-packages/transformers/utils/hub.py in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     340     try:
#     341         # Load from URL or cache if already cached
# --> 342         resolved_file = hf_hub_download(
#     343             path_or_repo_id,
#     344             filename,
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     112             kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
#     113
# --> 114         return fn(*args, **kwargs)
#     115
#     116     return _inner_fn  # type: ignore
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, resume_download, force_filename, local_dir_use_symlinks)
#     858         )
#     859     else:
# --> 860         return _hf_hub_download_to_cache_dir(
#     861             # Destination
#     862             cache_dir=cache_dir,
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, endpoint, etag_timeout, headers, proxies, token, local_files_only, force_download)
#    1007     Path(lock_path).parent.mkdir(parents=True, exist_ok=True)
#    1008     with WeakFileLock(lock_path):
# -> 1009         _download_to_tmp_and_move(
#    1010             incomplete_path=Path(blob_path + ".incomplete"),
#    1011             destination_path=Path(blob_path),
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py in _download_to_tmp_and_move(incomplete_path, destination_path, url_to_download, proxies, headers, expected_size, filename, force_download)
#    1541             _check_disk_space(expected_size, destination_path.parent)
#    1542
# -> 1543         http_get(
#    1544             url_to_download,
#    1545             f,
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py in http_get(url, temp_file, proxies, resume_size, headers, expected_size, displayed_filename, _nb_retries, _tqdm_bar)
#     453                 if chunk:  # filter out keep-alive new chunks
#     454                     progress.update(len(chunk))
# --> 455                     temp_file.write(chunk)
#     456                     new_resume_size += len(chunk)
#     457                     # Some data has been downloaded from the server so we reset the number of retries.
#
# OSError: [Errno 28] No space left on device

# %%
from langchain_huggingface import HuggingFacePipeline
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

model_id = "gpt2"
model = AutoModelForCausalLM.from_pretrained(model_id)
tokenizer =AutoTokenizer.from_pretrained(model_id)


pipe=pipeline("text-generation",model=model,tokenizer=tokenizer,max_new_tokens=100)

hf = HuggingFacePipeline(pipeline=pipe)

# %%
hf

# %%
hf.invoke("hi hello how are you?")

# %%
template = """Quiestion: {queston}
give me a answer in detail manner and in step by step manner"""

prompt = PromptTemplate(template=template,input_variables=["question"])

# %%
llm_chain = LLMChain(llm=hf,prompt=prompt)

# %%
llm_chain.invoke(question)

# %% [markdown]
# #### Mistral Model
# - mistralai/Mistral-7B-Instruct-v0.2

# %%
from langchain_huggingface import HuggingFacePipeline
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

model_id = "mistralai/Mistral-7B-Instruct-v0.2"
model = AutoModelForCausalLM.from_pretrained(model_id)
tokenizer =AutoTokenizer.from_pretrained(model_id)


pipe=pipeline("text-generation",model=model,tokenizer=tokenizer,max_new_tokens=100)

hf = HuggingFacePipeline(pipeline=pipe)

# %%
hf

# %%
hf.invoke("hi hello how are you?")

# %%
template = """Quiestion: {queston}
give me a answer in detail manner and in step by step manner"""

prompt = PromptTemplate(template=template,input_variables=["question"])

# %%
llm_chain = LLMChain(llm=hf,prompt=prompt)

# %%
llm_chain.invoke(question)
